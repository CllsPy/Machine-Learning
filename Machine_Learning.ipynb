# %% [markdown]
# <a href="https://colab.research.google.com/github/CllsPy/Machine-Learning/blob/main/Machine_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importar Bibliotecas

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import RandomOverSampler

# %% [markdown]
# ### Data Set Information:
#
# [Site do Repositórios de Dados](https://archive.ics.uci.edu/ml/index.php)

# %% [markdown]
# ### Chamar Base de Dados

# %%
pd.read_csv("/content/drive/MyDrive/Colab Notebooks/magic04.data")
# Out:
#         28.7967   16.0021  2.6449  0.3918  0.1982   27.7004    22.011  \
# 0       31.6036   11.7235  2.5185  0.5303  0.3773   26.2722   23.8238
# 1      162.0520  136.0310  4.0612  0.0374  0.0187  116.7410  -64.8580
# 2       23.8172    9.5728  2.3385  0.6147  0.3922   27.2107   -6.4633
# 3       75.1362   30.9205  3.1611  0.3168  0.1832   -5.5277   28.5525
# 4       51.6240   21.1502  2.9085  0.2420  0.1340   50.8761   43.1887
# ...         ...       ...     ...     ...     ...       ...       ...
# 19014   21.3846   10.9170  2.6161  0.5857  0.3934   15.2618   11.5245
# 19015   28.9452    6.7020  2.2672  0.5351  0.2784   37.0816   13.1853
# 19016   75.4455   47.5305  3.4483  0.1417  0.0549   -9.3561   41.0562
# 19017  120.5135   76.9018  3.9939  0.0944  0.0683    5.8043  -93.5224
# 19018  187.1814   53.0014  3.2093  0.2876  0.1539 -167.3125 -168.4558
#
#        -8.2027   40.092   81.8828  g
# 0      -9.9574   6.3609  205.2610  g
# 1     -45.2160  76.9600  256.7880  g
# ...

# %% [markdown]
# ### Nomear Colunas

# %%
name_col = ["flen", "fwid", "fsize", "fconc", "fconc1","fasy", "fm3log", "fm3trans", "falpha", "fdist", "class"]

# %% [markdown]
# ### Criar data frame e adicionar nomes

# %%
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/magic04.data", names = name_col)
print(df.head())
# Out:
#        flen      fwid   fsize   fconc  fconc1      fasy   fm3log  fm3trans  \
# 0   28.7967   16.0021  2.6449  0.3918  0.1982   27.7004  22.0110   -8.2027
# 1   31.6036   11.7235  2.5185  0.5303  0.3773   26.2722  23.8238   -9.9574
# 2  162.0520  136.0310  4.0612  0.0374  0.0187  116.7410 -64.8580  -45.2160
# 3   23.8172    9.5728  2.3385  0.6147  0.3922   27.2107  -6.4633   -7.1513
# 4   75.1362   30.9205  3.1611  0.3168  0.1832   -5.5277  28.5525   21.8393
#
#     falpha     fdist class
# 0  40.0920   81.8828     g
# 1   6.3609  205.2610     g
# 2  76.9600  256.7880     g
# 3  10.4490  116.7370     g
# 4   4.6480  356.4620     g

# %% [markdown]
# ### Transformar Classe em 1 ou 0

# %%
df["class"] = (df["class"]=="g").astype(int)

# %%
df.head()
# Out:
#        flen      fwid   fsize   fconc  fconc1      fasy   fm3log  fm3trans  \
# 0   28.7967   16.0021  2.6449  0.3918  0.1982   27.7004  22.0110   -8.2027
# 1   31.6036   11.7235  2.5185  0.5303  0.3773   26.2722  23.8238   -9.9574
# 2  162.0520  136.0310  4.0612  0.0374  0.0187  116.7410 -64.8580  -45.2160
# 3   23.8172    9.5728  2.3385  0.6147  0.3922   27.2107  -6.4633   -7.1513
# 4   75.1362   30.9205  3.1611  0.3168  0.1832   -5.5277  28.5525   21.8393
#
#     falpha     fdist  class
# 0  40.0920   81.8828      1
# 1   6.3609  205.2610      1
# 2  76.9600  256.7880      1
# 3  10.4490  116.7370      1
# 4   4.6480  356.4620      1

# %% [markdown]
# ### Matplot e os gráficos

# %%
for label in name_col[:-1]:
  plt.hist(df[df["class"]==0][label], color='purple', label='gamma', alpha=0.7, density=True)
  plt.hist(df[df["class"]==1][label], color='orange', label='hadron', alpha=0.7, density=True)
  plt.title(label)
  plt.ylabel("Probability")
  plt.xlabel(label)
  plt.legend()
  plt.show()

# %% [markdown]
# ### Train, Validation, Teste

# %%
train, valid, test = np.split(df.sample(frac=1), [int(0.6*len(df)), int(0.8*len(df))])

# %%
def scale_dataset(dataframe, oversample = False):

  X = dataframe[dataframe.columns[:-1]].values
  y = dataframe[dataframe.columns[-1]].values

  scaler = StandardScaler()
  X = scaler.fit_transform(X)

  if oversample:
    ros = RandomOverSampler()
    X, y = ros.fit_resample(X, y)

  data = np.hstack((X, np.reshape(y, (-1, 1))))
  return data, X, y

# %%
train, X_train, y_train = scale_dataset(train, oversample=True)
valid, X_valid, y_valid = scale_dataset(valid, oversample=False)
test, X_test, y_test = scale_dataset(test, oversample=False)

# %% [markdown]
# # kNN

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report

# %%
knn_model = KNeighborsClassifier(n_neighbors= 10)
knn_model.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=10)

# %%
y_pred = knn_model.predict(X_test)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.77      0.75      1338
#            1       0.87      0.85      0.86      2466
#
#     accuracy                           0.82      3804
#    macro avg       0.81      0.81      0.81      3804
# weighted avg       0.83      0.82      0.82      3804
